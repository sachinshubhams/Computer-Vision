# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2 as cv

# %%
img=cv.imread('Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB
# OPENCV --> BGR

# %%
new_img=cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(new_img)

# %%
img_gray=cv.imread('Computer-Vision-with-Python/DATA/00-puppy.jpg',cv.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
img_gray.min()
# Out:
# 1

# %%
img_gray.max()
# Out:
# 209

# %%
plt.imshow(img_gray, cmap='gray')

# %%
new_img.shape
# Out:
# (1300, 1950, 3)

# %%
img_resize=cv.resize(new_img,(1000,400))

# %%
plt.imshow(img_resize)

# %%
w_ratio=0.6
h_ratio=0.4

# %%
new_img_ratio=cv.resize(new_img,(0,0),new_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img_ratio)

# %%
new_img_ratio.shape
# Out:
# (520, 1170, 3)

# %%
#flip image over horizontal and vertical axis

# %%
new_img=cv.flip(new_img,1)# 0 --> upside down

# %%
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv.imwrite('updated_new.jpg', new_img)
# Out:
# True

# %%
#resize the image
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(new_img)

# %%
import cv2 as cv
fix_img=cv.imread('Computer-Vision-with-Python/DATA/00-puppy.jpg')
cv.imshow('Puppy',fix_img)
cv.waitKey()
